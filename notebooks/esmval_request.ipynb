# %%
# selection files for esmval

import yaml

# %%
with open("../selection_files/cmip6-request.yaml") as f:
    for doc in yaml.safe_load_all(f):
        print(doc)
# Out:
# {'experiment': ['DECK', 'historical', 'ScenarioMIP simulations'], 'mip_table': 'aero', 'variable_name': 'abs550aer'}
# {'experiment': ['DECK', 'historical', 'ScenarioMIP simulations'], 'mip_table': 'cfDay', 'variable_name': 'albisccp'}
# {'experiment': ['DECK', 'historical', 'ScenarioMIP simulations'], 'mip_table': 'CFday', 'variable_name': 'albisccp'}
# {'experiment': ['DECK', 'historical', 'ScenarioMIP simulations'], 'mip_table': 'day', 'variable_name': 'albisccp'}
# {'experiment': ['DECK', 'historical', 'ScenarioMIP simulations'], 'mip_table': 'AERmon', 'variable_name': 'albs'}
# {'experiment': ['DECK', 'historical', 'ScenarioMIP simulations'], 'mip_table': 'AERmon', 'variable_name': 'albsrfc'}
# {'experiment': ['DECK', 'historical', 'ScenarioMIP simulations'], 'mip_table': 'fx', 'variable_name': 'areacella'}
# {'experiment': ['DECK', 'historical', 'ScenarioMIP simulations'], 'mip_table': 'IfxAnt', 'variable_name': 'areacellg'}
# ...

# %%
print(doc)
# Out:
# {'experiment': ['DECK', 'historical', 'ScenarioMIP simulations'], 'mip_table': 'aero', 'variable_name': 'abs550aer'}
